# %%
1. For i = 1 to k:
       Generate Ui ~ Uniform(0,1)
       Compute Ei = -(1/λ) * ln(Ui)
2. Return X = sum(Ei)
# Out:
#   Cell In[2], line 1
#     1. For i = 1 to k:
#        ^
# SyntaxError: invalid syntax
